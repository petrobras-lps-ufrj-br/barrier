# %% [markdown]
# # How to connect to Cognite Database?

# %%
# !pip install cognite-sdk -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prefect 3.6.6 requires graphviz>=0.20.1, but you have graphviz 0.8.4 which is incompatible.

# %%
from cognite.client import CogniteClient, ClientConfig
from cognite.client.credentials import OAuthClientCredentials
from loguru import logger

# %%
class DataLoader:
    def __init__(self):
        pass


class Cognite(DataLoader):
    def __init__(self,
                 name : str,
                 client_id : str,
                 client_secret : str,
                 tenant_id : str,
                 project   : str="publicdata",
                ):

        self.name = name
        self.tenant_id = tenant_id
        self.project = project
        self.base_url = f"https://api.cognitedata.com"
        self.url = f"https://login.microsoftonline.com/{tenant_id}/oauth2/v2.0/token"
        self._client_id = client_id
        self._client_secret = client_secret 
        self._credentials = OAuthClientCredentials(
            token_url = self.url,
            client_id = self._client_id,
            client_secret = self._client_secret,
            scopes = [f"{self.base_url}/.default"],
        )
        self._config = ClientConfig(
            client_name=name , 
            project=project, 
            credentials=self._credentials, 
            base_url=self.base_url)
        self._client = CogniteClient( self._config )

        try:
            token_status = self._client.iam.token.inspect()
            print(token_status)
            logger.info(f"{token_status.projects[0].project_url_name}")
        except Exception as e:
            print(e)


reader = Cognite("compressor", client_id=CLIENT_ID, client_secret=CLIENT_SECRET, tenant_id=TENANT_ID)
# Out:
# 2025-12-16 18:56:32.112 | INFO     | __main__:__init__:38 - publicdata
# {
#     "subject": "84b88c0a-90c4-4495-8967-a19a4260393a",
#     "projects": [
#         {
#             "project_url_name": "publicdata",
#             "groups": [
#                 29915539313054,
#                 72115339228283,
#                 269521164420097
#             ]
#         },
#         {
#             "project_url_name": "publicdatacdm",
#             "groups": [
#                 2835077484049827
#             ]
#         }
#     ],
#     "capabilities": [
#         {
#             "groups_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "assets_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "events_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "raw_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "time_series_acl": {
#                 "actions": [
#                     "WRITE"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "threed_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "sequences_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "datasets_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "relationships_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "projects_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "annotations_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "files_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             2452112635370053,
#                             8468679571033524
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "time_series_subscriptions_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "groups_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "currentuserscope": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "assets_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "events_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "raw_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "time_series_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "threed_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "sequences_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "analytics_acl": {
#                 "actions": [
#                     "READ",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "datasets_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "files_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "datasetScope": {
#                         "ids": [
#                             2452112635370053,
#                             8468679571033524
#                         ]
#                     }
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "relationships_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "data_models_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "data_model_instances_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "time_series_subscriptions_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdata"
#                 ]
#             }
#         },
#         {
#             "projects_acl": {
#                 "actions": [
#                     "LIST",
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "groups_acl": {
#                 "actions": [
#                     "LIST",
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "raw_acl": {
#                 "actions": [
#                     "READ",
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "data_models_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "data_model_instances_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "datasets_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "extraction_pipelines_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "extraction_runs_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "extraction_configs_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "functions_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "sessions_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "transformations_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "file_pipelines_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "security_categories_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "hosted_extractors_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "workflow_orchestration_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "security_categories_acl": {
#                 "actions": [
#                     "LIST"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "time_series_subscriptions_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "location_filters_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "files_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         },
#         {
#             "threed_acl": {
#                 "actions": [
#                     "READ"
#                 ],
#                 "scope": {
#                     "all": {}
#                 }
#             },
#             "projectScope": {
#                 "projects": [
#                     "publicdatacdm"
#                 ]
#             }
#         }
#     ]
# }
